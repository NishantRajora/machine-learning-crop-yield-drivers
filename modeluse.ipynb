# %%
import pandas as pd
import numpy as np
import joblib
from sklearn.preprocessing import StandardScaler

# %%
model = joblib.load("xgboost_model.pkl")
scaler = joblib.load("scaler.pkl")

# %%
feature_columns = [
    'Year',
    'Decade',
    'State_encoded',
    'Crop_encoded',
    'Season_encoded',
    'Area_ha',
    'N_req_kg_per_ha',
    'P_req_kg_per_ha',
    'K_req_kg_per_ha',
    'Temperature_C',
    'Humidity_%',
    'pH',
    'Rainfall_mm',
    'Wind_Speed_m_s',
    'Solar_Radiation_MJ_m2_day'
]

# %%
print(scaler.feature_names_in_)
feature_columns = scaler.feature_names_in_
new_data = new_data[feature_columns]
new_data_scaled = scaler.transform(new_data)
# Out:
# ['Year' 'Decade' 'Crop_encoded' 'Season_encoded' 'Area_ha'
#  'N_req_kg_per_ha' 'P_req_kg_per_ha' 'K_req_kg_per_ha' 'Humidity_%'
#  'Rainfall_mm']

# %%
# Load model and scaler
model = joblib.load("xgboost_model.pkl")
scaler = joblib.load("scaler.pkl")

# Create input
new_data = pd.DataFrame([{
    'Year': 2022,
    'Decade': 2020,
    'State_encoded': 5,
    'Crop_encoded': 3,
    'Season_encoded': 2,
    'Area_ha': 5000,
    'N_req_kg_per_ha': 80,
    'P_req_kg_per_ha': 40,
    'K_req_kg_per_ha': 50,
    'Temperature_C': 28,
    'Humidity_%': 70,
    'pH': 6.5,
    'Rainfall_mm': 900,
    'Wind_Speed_m_s': 2.5,
    'Solar_Radiation_MJ_m2_day': 20
}])

# Match training feature order
new_data = new_data[scaler.feature_names_in_]

# Scale
new_data_scaled = scaler.transform(new_data)

# Predict
prediction = model.predict(new_data_scaled)

print("🌾 Predicted Yield:", round(prediction[0], 2), "kg/ha")
# Out:
# 🌾 Predicted Yield: 10936.39 kg/ha
